# %%
import numpy as np
import pandas as pd
import os
import sys
import project_functions as p

df1 = p.load_and_process('../../data/raw/twitchdataset.csv')
df1
# Out:
# <style  type="text/css" >
#     #T_c6bfb_ th {
#           background: #6441A4;
#           color: white;
#           font-family: verdana;
#     }    #T_c6bfb_ td {
#           font-family: verdana;
#     }    #T_c6bfb_ tr:nth-of-type(odd) {
#           background: #DCDCDC;
#     }    #T_c6bfb_ tr:nth-of-type(even) {
#           background: white;
#     }    #T_c6bfb_ tr:hover {
#           background-color: #F5DEF9;
#     }</style><table id="T_c6bfb_" ><thead>    <tr>        <th class="col_heading level0 col0" >Ranking</th>        <th class="col_heading level0 col1" >Stream Name</th>        <th class="col_heading level0 col2" >Watch Time (Hours)</th>        <th class="col_heading level0 col3" >Stream Time (Hours)</th>        <th class="col_heading level0 col4" >Viewers (Peak)</th>        <th class="col_heading level0 col5" >Viewers (Average)</th>        <th class="col_heading level0 col6" >Followers (Total)</th>        <th class="col_heading level0 col7" >Followers (Gained)</th>        <th class="col_heading level0 col8" >Viewers (Gained)</th>        <th class="col_heading level0 col9" >Partnered</th>        <th class="col_heading level0 col10" >Audience Type (Mature)</th>        <th class="col_heading level0 col11" >Language</th>        <th class="col_heading level0 col12" >Primary Game</th>        <th class="col_heading level0 col13" >Secondary Game</th>        <th class="col_heading level0 col14" >Tertiary Game</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c6bfb_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c6bfb_row0_col1" class="data row0 col1" >xQcOW</td>
#                         <td id="T_c6bfb_row0_col2" class="data row0 col2" >7333609065</td>
#                         <td id="T_c6bfb_row0_col3" class="data row0 col3" >215670</td>
#                         <td id="T_c6bfb_row0_col4" class="data row0 col4" >222720</td>
#                         <td id="T_c6bfb_row0_col5" class="data row0 col5" >32913</td>
#                         <td id="T_c6bfb_row0_col6" class="data row0 col6" >3691010</td>
#                         <td id="T_c6bfb_row0_col7" class="data row0 col7" >2051895</td>
#                         <td id="T_c6bfb_row0_col8" class="data row0 col8" >109735389</td>
#                         <td id="T_c6bfb_row0_col9" class="data row0 col9" >True</td>
#                         <td id="T_c6bfb_row0_col10" class="data row0 col10" >False</td>
#                         <td id="T_c6bfb_row0_col11" class="data row0 col11" >English</td>
#                         <td id="T_c6bfb_row0_col12" class="data row0 col12" >Just Chatting</td>
#                         <td id="T_c6bfb_row0_col13" class="data row0 col13" >Among Us</td>
#                         <td id="T_c6bfb_row0_col14" class="data row0 col14" >Overwatch</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6bfb_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_c6bfb_row1_col1" class="data row1 col1" >Gaules</td>
#                         <td id="T_c6bfb_row1_col2" class="data row1 col2" >6314532585</td>
#                         <td id="T_c6bfb_row1_col3" class="data row1 col3" >515595</td>
#                         <td id="T_c6bfb_row1_col4" class="data row1 col4" >387315</td>
#                         <td id="T_c6bfb_row1_col5" class="data row1 col5" >12254</td>
#                         <td id="T_c6bfb_row1_col6" class="data row1 col6" >1966465</td>
#                         <td id="T_c6bfb_row1_col7" class="data row1 col7" >1141123</td>
#                         <td id="T_c6bfb_row1_col8" class="data row1 col8" >112807468</td>
#                         <td id="T_c6bfb_row1_col9" class="data row1 col9" >True</td>
#                         <td id="T_c6bfb_row1_col10" class="data row1 col10" >True</td>
#                         <td id="T_c6bfb_row1_col11" class="data row1 col11" >Portuguese</td>
#                         <td id="T_c6bfb_row1_col12" class="data row1 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_c6bfb_row1_col13" class="data row1 col13" >Among Us</td>
#                         <td id="T_c6bfb_row1_col14" class="data row1 col14" >PLAYERUNKNOWN</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6bfb_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_c6bfb_row2_col1" class="data row2 col1" >summit1g</td>
#                         <td id="T_c6bfb_row2_col2" class="data row2 col2" >6235007490</td>
#                         <td id="T_c6bfb_row2_col3" class="data row2 col3" >216000</td>
#                         <td id="T_c6bfb_row2_col4" class="data row2 col4" >310998</td>
#                         <td id="T_c6bfb_row2_col5" class="data row2 col5" >25931</td>
#                         <td id="T_c6bfb_row2_col6" class="data row2 col6" >5374710</td>
#                         <td id="T_c6bfb_row2_col7" class="data row2 col7" >1402547</td>
#                         <td id="T_c6bfb_row2_col8" class="data row2 col8" >91501875</td>
#                         <td id="T_c6bfb_row2_col9" class="data row2 col9" >True</td>
#                         <td id="T_c6bfb_row2_col10" class="data row2 col10" >False</td>
#                         <td id="T_c6bfb_row2_col11" class="data row2 col11" >English</td>
#                         <td id="T_c6bfb_row2_col12" class="data row2 col12" >Escape From Tarkov</td>
#                         <td id="T_c6bfb_row2_col13" class="data row2 col13" >Sea of Thieves</td>
#                         <td id="T_c6bfb_row2_col14" class="data row2 col14" >Grand Theft Auto V</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6bfb_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_c6bfb_row3_col1" class="data row3 col1" >ESL_CSGO</td>
#                         <td id="T_c6bfb_row3_col2" class="data row3 col2" >4764929775</td>
#                         <td id="T_c6bfb_row3_col3" class="data row3 col3" >517965</td>
#                         <td id="T_c6bfb_row3_col4" class="data row3 col4" >300575</td>
#                         <td id="T_c6bfb_row3_col5" class="data row3 col5" >9249</td>
#                         <td id="T_c6bfb_row3_col6" class="data row3 col6" >4195657</td>
#                         <td id="T_c6bfb_row3_col7" class="data row3 col7" >870484</td>
#                         <td id="T_c6bfb_row3_col8" class="data row3 col8" >126008641</td>
#                         <td id="T_c6bfb_row3_col9" class="data row3 col9" >True</td>
#                         <td id="T_c6bfb_row3_col10" class="data row3 col10" >False</td>
#                         <td id="T_c6bfb_row3_col11" class="data row3 col11" >English</td>
#                         <td id="T_c6bfb_row3_col12" class="data row3 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_c6bfb_row3_col13" class="data row3 col13" >nan</td>
#                         <td id="T_c6bfb_row3_col14" class="data row3 col14" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6bfb_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_c6bfb_row4_col1" class="data row4 col1" >NICKMERCS</td>
#                         <td id="T_c6bfb_row4_col2" class="data row4 col2" >3853252845</td>
#                         <td id="T_c6bfb_row4_col3" class="data row4 col3" >131880</td>
#                         <td id="T_c6bfb_row4_col4" class="data row4 col4" >163241</td>
#                         <td id="T_c6bfb_row4_col5" class="data row4 col5" >29183</td>
#                         <td id="T_c6bfb_row4_col6" class="data row4 col6" >4415637</td>
#                         <td id="T_c6bfb_row4_col7" class="data row4 col7" >1337535</td>
#                         <td id="T_c6bfb_row4_col8" class="data row4 col8" >49164651</td>
#                         <td id="T_c6bfb_row4_col9" class="data row4 col9" >True</td>
#                         <td id="T_c6bfb_row4_col10" class="data row4 col10" >False</td>
#                         <td id

# %%
df2 = p.most_followers_gained('../../data/raw/twitchdataset.csv')
df2
#a representation of the table comparing followers gained and viewers gained in original order
# Out:
#            screen name  followers gained  views gained
# 0                xQcOW           2051895     109735389
# 1               Gaules           1141123     112807468
# 2             summit1g           1402547      91501875
# 3             ESL_CSGO            870484     126008641
# 4            NICKMERCS           1337535      49164651
# ...                ...               ...           ...
# 8795  MARCUSakaAPOSTLE             19618        190090
# 8796     MIMISHKA_MEOW              3204        398018
# 8797           MySteam             10273        264848
# 8798        Iker_Guide              5245        243384
# 8799          dhary_xd              2921        927197
#
# [8800 rows x 3 columns]

# %%
import seaborn as sns

df3 = df2.drop("screen name", axis=1)
corr = df3.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
#Very simple visual showing the correlation between an increase in followers vs an increase in views.

# %%
df3.plot(kind='scatter', x='followers gained', y='views gained')
# Out:
# <AxesSubplot:xlabel='followers gained', ylabel='views gained'>

# %%
#scatter graph showing that majority of streamers gaining followers are gainging about 1 view per follower gained

# %%
#Ihnore the rest, I was starting task 5 before i realized i didn't start a new notebook

# %%
#Task 5: 
#From the above scatter graph, we see that majority of streamers either get 1 view per no follower gained, or a decimal number of views per follower gained. This can be expressed as new follower's
#don't contribute as much to the channel as concurrent viewers. To answer how gaining followers affects a streamers revenue, which is generated based on many elements including views per month,
#followers, average viewers, stream time and taking into account that donations and indirect monetary gains are linearly connected to each of those factors. We can see that newer viewers/followers
#do not contribute as much as concurrent viewers, this may be that many newer viewers aren't used to the streamer, or they may simply be uncomfortable with donating due to their financial statues.

# %%
df4 = p.watch_stream('../../data/raw/twitchdataset.csv')

# %%
df4.plot(kind='scatter', x='stream time', y='average viewers')
# Out:
# <AxesSubplot:xlabel='stream time', ylabel='average viewers'>

# %%
#This graph displays the total streaming times of the streamers vs the average viewers they get. Note that this takes into account that some streamers peak at multiple times the viewers that they
#usually get and vice versa for the lowest count.
