# %%
import pandas as pd
df = pd.read_csv('../raw/twitchdataset.csv')
df.to_csv(r'../raw/twitchdataset.csv', index = False)

# %%
df
# Out:
#                                         profile picture  top count  \
# 0     https://static-cdn.jtvnw.net/jtv_user_pictures...          1
# 1     https://static-cdn.jtvnw.net/jtv_user_pictures...          2
# 2     https://static-cdn.jtvnw.net/jtv_user_pictures...          3
# 3     https://static-cdn.jtvnw.net/jtv_user_pictures...          4
# 4     https://static-cdn.jtvnw.net/jtv_user_pictures...          5
# ...                                                 ...        ...
# 8795  https://static-cdn.jtvnw.net/jtv_user_pictures...       8796
# 8796  https://static-cdn.jtvnw.net/jtv_user_pictures...       8797
# 8797  https://static-cdn.jtvnw.net/jtv_user_pictures...       8798
# 8798  https://static-cdn.jtvnw.net/jtv_user_pictures...       8799
# 8799  https://static-cdn.jtvnw.net/jtv_user_pictures...       8800
#
#            screen name  watch time  stream time  peak viewers  \
# 0                xQcOW  7333609065       215670        222720
# ...
