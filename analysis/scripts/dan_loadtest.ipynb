# %%
import pandas as pd
import numpy as np
import os
import sys

from project_functions import load_and_process
df = load_and_process('../../data/raw/twitchdataset.csv')
df
# Out:
# <style  type="text/css" >
#     #T_b90a8_ th {
#           background: #6441A4;
#           color: white;
#           font-family: verdana;
#     }    #T_b90a8_ td {
#           font-family: verdana;
#     }    #T_b90a8_ tr:nth-of-type(odd) {
#           background: #DCDCDC;
#     }    #T_b90a8_ tr:nth-of-type(even) {
#           background: white;
#     }    #T_b90a8_ tr:hover {
#           background-color: #F5DEF9;
# ...
