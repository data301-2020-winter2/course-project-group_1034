# %%
import numpy as np
import seaborn as sns
import pandas as pd
import os
import sys
import project_functions as p
import matplotlib
from matplotlib import pyplot as plt

# %%
df2 = p.most_followers_gained('../../data/raw/twitchdataset.csv')
df3 = df2.drop("screen name", axis=1)
df3.plot(kind='scatter', x='followers gained', y='views gained')
# Out:
# <AxesSubplot:xlabel='followers gained', ylabel='views gained'>

# %%
#Task 5: 
#From the above scatter graph, we see that majority of streamers either get 1 view per no follower gained, or a decimal number of views per follower gained. This can be expressed as new follower's
#don't contribute as much to the channel as concurrent viewers. To answer how gaining followers affects a streamers revenue, which is generated based on many elements including views per month,
#followers, average viewers, stream time and taking into account that donations and indirect monetary gains are linearly connected to each of those factors. We can see that newer viewers/followers
#do not contribute as much as concurrent viewers, this may be that many newer viewers aren't used to the streamer, or they may simply be uncomfortable with donating due to their financial statues.

# %%
df4 = p.watch_stream('../../data/raw/twitchdataset.csv')
df4.plot(kind='scatter', x='stream time', y='average viewers')
# Out:
# <AxesSubplot:xlabel='stream time', ylabel='average viewers'>

# %%
#This graph displays the total streaming times of the streamers vs the average viewers they get. Note that this takes into account that some streamers peak at multiple times the viewers that they
#usually get and vice versa for the lowest count. Most streamers seen to average around the 15,000 viewer mark whereas streamers who have been streaming longer have lower averages, most likely 
#due to the fact that they've been streaming since before the platform got popular. This means there were far less viewers on Twitch overall at the times, bringing down the average viewer value
#for older "OG" streamers. A higher average viewer count also means that you will have higher chances for donations, paid subscriptions, paid bits (indirect donations) and probably paid sponsors
#for either playing certain newer games or by other outside companies whishing to get some exposure. Holding streaming time constant, this means that more average concurrent viewers means more 
#revenue generated. Although since the older streamers have 2, 3, 4 or even 5 times the amount of stream time, and they are generally (but not always) the top of twitch, they will generate vast
#amounts of revenue far greater than newer streamers with less stream time. This previous statement takes into account that older streamers streaming in the early days of Twitch before many paid
#subscription options, bits and rampant donation for Text to Speech spam, there was generally less money to be made. However, there was much more exposure for already set streamers when Twitch
#blew up, causing people to come flooding in, and to be recommended these old established streams. Resulting in an indirect increase in revenue as average viewers for these streams skyrocketed.

# %%
df5 = p.games_played('../../data/raw/twitchdataset.csv')

# %%
#First off this took me like 7 hours so i am super proud of this. 
#This graph displays data on the top 3 games played by streamers. 
#I began by compiling repeated games that streamers use and sum the occurance each time the games is stateted in our data.
#This bar graph shows the most popular games played by the top streamers.
#We can see "Just Chatting" is the most played with League of Legneds in a distant second. 
#From this analysis we can infer what games are the most watched.
#This information would be helpful to any user who would like to understand wthe most demanded games in the industry
