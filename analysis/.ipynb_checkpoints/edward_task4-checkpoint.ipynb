# %%
import numpy as np
import pandas as pd
import os
import sys
from scripts.project_functions import (load_and_process)

df1 = load_and_process('../data/raw/twitchdataset.csv')
df1
# Out:
# <style  type="text/css" >
#     #T_618cd_ th {
#           background: #6441A4;
#           color: white;
#           font-family: verdana;
#     }    #T_618cd_ td {
#           font-family: verdana;
#     }    #T_618cd_ tr:nth-of-type(odd) {
#           background: #DCDCDC;
#     }    #T_618cd_ tr:nth-of-type(even) {
#           background: white;
#     }    #T_618cd_ tr:hover {
#           background-color: #F5DEF9;
#     }</style><table id="T_618cd_" ><thead>    <tr>        <th class="col_heading level0 col0" >Ranking</th>        <th class="col_heading level0 col1" >Stream Name</th>        <th class="col_heading level0 col2" >Watch Time (Hours)</th>        <th class="col_heading level0 col3" >Stream Time (Hours)</th>        <th class="col_heading level0 col4" >Viewers (Peak)</th>        <th class="col_heading level0 col5" >Viewers (Average)</th>        <th class="col_heading level0 col6" >Followers (Total)</th>        <th class="col_heading level0 col7" >Followers (Gained)</th>        <th class="col_heading level0 col8" >Viewers (Gained)</th>        <th class="col_heading level0 col9" >Partnered</th>        <th class="col_heading level0 col10" >Audience Type (Mature)</th>        <th class="col_heading level0 col11" >Language</th>        <th class="col_heading level0 col12" >Primary Game</th>        <th class="col_heading level0 col13" >Secondary Game</th>        <th class="col_heading level0 col14" >Tertiary Game</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_618cd_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_618cd_row0_col1" class="data row0 col1" >xQcOW</td>
#                         <td id="T_618cd_row0_col2" class="data row0 col2" >7333609065</td>
#                         <td id="T_618cd_row0_col3" class="data row0 col3" >215670</td>
#                         <td id="T_618cd_row0_col4" class="data row0 col4" >222720</td>
#                         <td id="T_618cd_row0_col5" class="data row0 col5" >32913</td>
#                         <td id="T_618cd_row0_col6" class="data row0 col6" >3691010</td>
#                         <td id="T_618cd_row0_col7" class="data row0 col7" >2051895</td>
#                         <td id="T_618cd_row0_col8" class="data row0 col8" >109735389</td>
#                         <td id="T_618cd_row0_col9" class="data row0 col9" >True</td>
#                         <td id="T_618cd_row0_col10" class="data row0 col10" >False</td>
#                         <td id="T_618cd_row0_col11" class="data row0 col11" >English</td>
#                         <td id="T_618cd_row0_col12" class="data row0 col12" >Just Chatting</td>
#                         <td id="T_618cd_row0_col13" class="data row0 col13" >Among Us</td>
#                         <td id="T_618cd_row0_col14" class="data row0 col14" >Overwatch</td>
#             </tr>
#             <tr>
#                                 <td id="T_618cd_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_618cd_row1_col1" class="data row1 col1" >Gaules</td>
#                         <td id="T_618cd_row1_col2" class="data row1 col2" >6314532585</td>
#                         <td id="T_618cd_row1_col3" class="data row1 col3" >515595</td>
#                         <td id="T_618cd_row1_col4" class="data row1 col4" >387315</td>
#                         <td id="T_618cd_row1_col5" class="data row1 col5" >12254</td>
#                         <td id="T_618cd_row1_col6" class="data row1 col6" >1966465</td>
#                         <td id="T_618cd_row1_col7" class="data row1 col7" >1141123</td>
#                         <td id="T_618cd_row1_col8" class="data row1 col8" >112807468</td>
#                         <td id="T_618cd_row1_col9" class="data row1 col9" >True</td>
#                         <td id="T_618cd_row1_col10" class="data row1 col10" >True</td>
#                         <td id="T_618cd_row1_col11" class="data row1 col11" >Portuguese</td>
#                         <td id="T_618cd_row1_col12" class="data row1 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_618cd_row1_col13" class="data row1 col13" >Among Us</td>
#                         <td id="T_618cd_row1_col14" class="data row1 col14" >PLAYERUNKNOWN</td>
#             </tr>
#             <tr>
#                                 <td id="T_618cd_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_618cd_row2_col1" class="data row2 col1" >summit1g</td>
#                         <td id="T_618cd_row2_col2" class="data row2 col2" >6235007490</td>
#                         <td id="T_618cd_row2_col3" class="data row2 col3" >216000</td>
#                         <td id="T_618cd_row2_col4" class="data row2 col4" >310998</td>
#                         <td id="T_618cd_row2_col5" class="data row2 col5" >25931</td>
#                         <td id="T_618cd_row2_col6" class="data row2 col6" >5374710</td>
#                         <td id="T_618cd_row2_col7" class="data row2 col7" >1402547</td>
#                         <td id="T_618cd_row2_col8" class="data row2 col8" >91501875</td>
#                         <td id="T_618cd_row2_col9" class="data row2 col9" >True</td>
#                         <td id="T_618cd_row2_col10" class="data row2 col10" >False</td>
#                         <td id="T_618cd_row2_col11" class="data row2 col11" >English</td>
#                         <td id="T_618cd_row2_col12" class="data row2 col12" >Escape From Tarkov</td>
#                         <td id="T_618cd_row2_col13" class="data row2 col13" >Sea of Thieves</td>
#                         <td id="T_618cd_row2_col14" class="data row2 col14" >Grand Theft Auto V</td>
#             </tr>
#             <tr>
#                                 <td id="T_618cd_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_618cd_row3_col1" class="data row3 col1" >ESL_CSGO</td>
#                         <td id="T_618cd_row3_col2" class="data row3 col2" >4764929775</td>
#                         <td id="T_618cd_row3_col3" class="data row3 col3" >517965</td>
#                         <td id="T_618cd_row3_col4" class="data row3 col4" >300575</td>
#                         <td id="T_618cd_row3_col5" class="data row3 col5" >9249</td>
#                         <td id="T_618cd_row3_col6" class="data row3 col6" >4195657</td>
#                         <td id="T_618cd_row3_col7" class="data row3 col7" >870484</td>
#                         <td id="T_618cd_row3_col8" class="data row3 col8" >126008641</td>
#                         <td id="T_618cd_row3_col9" class="data row3 col9" >True</td>
#                         <td id="T_618cd_row3_col10" class="data row3 col10" >False</td>
#                         <td id="T_618cd_row3_col11" class="data row3 col11" >English</td>
#                         <td id="T_618cd_row3_col12" class="data row3 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_618cd_row3_col13" class="data row3 col13" >nan</td>
#                         <td id="T_618cd_row3_col14" class="data row3 col14" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_618cd_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_618cd_row4_col1" class="data row4 col1" >NICKMERCS</td>
#                         <td id="T_618cd_row4_col2" class="data row4 col2" >3853252845</td>
#                         <td id="T_618cd_row4_col3" class="data row4 col3" >131880</td>
#                         <td id="T_618cd_row4_col4" class="data row4 col4" >163241</td>
#                         <td id="T_618cd_row4_col5" class="data row4 col5" >29183</td>
#                         <td id="T_618cd_row4_col6" class="data row4 col6" >4415637</td>
#                         <td id="T_618cd_row4_col7" class="data row4 col7" >1337535</td>
#                         <td id="T_618cd_row4_col8" class="data row4 col8" >49164651</td>
#                         <td id="T_618cd_row4_col9" class="data row4 col9" >True</td>
#                         <td id="T_618cd_row4_col10" class="data row4 col10" >False</td>
#                         <td id

# %%
from scripts.project_functions import (test)
df2 = test('../data/raw/twitchdataset.csv')
df8 = (
    pd.DataFrame(df2).rename(columns={"first category":"game"})
    .rename(columns={"second category":"game2"})
    .rename(columns={"third category":"game3"})
)
df8
# Out:
#            screen name                              game              game2  \
# 0                xQcOW                     Just Chatting           Among Us
# 1               Gaules  Counter-Strike: Global Offensive           Among Us
# 2             summit1g                Escape From Tarkov     Sea of Thieves
# 3             ESL_CSGO  Counter-Strike: Global Offensive                NaN
# 4            NICKMERCS      Call Of Duty: Modern Warfare           Fortnite
# ...                ...                               ...                ...
# 8795  MARCUSakaAPOSTLE                        Spellbreak      Rogue Company
# 8796     MIMISHKA_MEOW                         Overwatch      Just Chatting
# 8797           MySteam                            Dota 2      Just Chatting
# 8798        Iker_Guide                          Paladins  League of Legends
# 8799          dhary_xd                             Music      PLAYERUNKNOWN
#
#                                   game3
# 0                             Overwatch
# 1                         PLAYERUNKNOWN
# 2                    Grand Theft Auto V
# 3                                   NaN
# 4     Halo: The Master Chief Collection
# ...                                 ...
# 8795                       Apex Legends
# 8796                       Apex Legends
# 8797       Fall Guys: Ultimate Knockout
# 8798                              SMITE
# 8799                          Destiny 2
#
# [8800 rows x 4 columns]

# %%
# Get the count of each value
value_counts = df8['game'].value_counts()

# Select the values where the count is less than 142
to_remove = value_counts[value_counts <= 142].index

# Keep rows where the game column is not in to_remove
df9 = df8[~df8.game.isin(to_remove)] 
df10 = df9['game'].value_counts()
df10
# Out:
# Just Chatting                       1365
# League of Legends                    712
# Grand Theft Auto V                   578
# Fortnite                             463
# Call Of Duty: Modern Warfare         345
# Counter-Strike: Global Offensive     247
# World of Warcraft                    246
# VALORANT                             241
# Dota 2                               213
# Escape From Tarkov                   208
# FIFA 20                              198
# Minecraft                            191
# Hearthstone                          163
# Apex Legends                         156
# Dead by Daylight                     145
# Name: game, dtype: int64

# %%
# Get the count of each value
value_counts1 = df8['game2'].value_counts()

# Select the values where the count is less than 100
to_remove1 = value_counts1[value_counts1 <= 100].index

# Keep rows where the game2 column is not in to_remove
df11 = df8[~df8.game2.isin(to_remove1)] 
df12 = df11['game2'].value_counts()
df12
# Out:
# Just Chatting                       1264
# VALORANT                             541
# Call Of Duty: Modern Warfare         399
# League of Legends                    348
# Among Us                             307
# Unlisted on Twitch                   237
# Counter-Strike: Global Offensive     218
# Minecraft                            207
# Grand Theft Auto V                   199
# Fall Guys: Ultimate Knockout         184
# Escape From Tarkov                   179
# Fortnite                             149
# FIFA 21                              113
# Teamfight Tactics                    108
# Animal Crossing: New Horizons        106
# Name: game2, dtype: int64

# %%
# Get the count of each value
value_counts2 = df8['game3'].value_counts()

# Select the values where the count is less than 100
to_remove2 = value_counts2[value_counts2 <= 100].index

# Keep rows where the game3 column is not in to_remove
df13 = df8[~df8.game3.isin(to_remove2)] 
df14 = df13['game3'].value_counts()
df14
# Out:
# Just Chatting                       792
# Among Us                            438
# VALORANT                            424
# Call Of Duty: Modern Warfare        373
# Fall Guys: Ultimate Knockout        276
# League of Legends                   271
# Minecraft                           201
# Counter-Strike: Global Offensive    198
# Unlisted on Twitch                  185
# Grand Theft Auto V                  152
# Escape From Tarkov                  134
# Animal Crossing: New Horizons       129
# Fortnite                            118
# Apex Legends                        111
# Teamfight Tactics                   109
# Name: game3, dtype: int64

# %%
import matplotlib
from matplotlib import pyplot as plt
matplotlib.style.use('fivethirtyeight') 
df6 = (
    df10.plot.bar(x = "game", y = "value", rot = 90)
)
plt.title("Primary Games Played the Most")
plt.xlabel("Games")
plt.ylabel("Occurances of Game Betweem Streamers")
df6
# Out:
# <AxesSubplot:title={'center':'Primary Games Played the Most'}, xlabel='Games', ylabel='Occurances of Game Betweem Streamers'>

# %%
from matplotlib import pyplot as plt
matplotlib.style.use('fivethirtyeight') 
df7 = (
    df12.plot.bar(x = "game2", y = "value", rot = 90)
)
plt.title("Secondary Games Played the Most")
plt.xlabel("Games")
plt.ylabel("Occurances of Game Between Streamers")
df7
# Out:
# <AxesSubplot:title={'center':'Secondary Games Played the Most'}, xlabel='Games', ylabel='Occurances of Game Between Streamers'>

# %%
from matplotlib import pyplot as plt
matplotlib.style.use('fivethirtyeight') 
df15 = (
    df14.plot.bar(x = "game3", y = "value", rot = 90)
)
plt.title("Tertiary Games Played the Most")
plt.xlabel("Games")
plt.ylabel("Occurances of Game Between Streamers")
df15
# Out:
# <AxesSubplot:title={'center':'Tertiary Games Played the Most'}, xlabel='Games', ylabel='Occurances of Game Between Streamers'>

# %%
value_counts3 = df8[["game"]+['game2']+["game3"]].value_counts()
value_counts3
# Out:
# game                game2                  game3
# Fortnite            Just Chatting          Among Us                            30
# League of Legends   Just Chatting          Among Us                            25
#                                            VALORANT                            24
# Grand Theft Auto V  Just Chatting          Counter-Strike: Global Offensive    23
#                                            League of Legends                   22
#                                                                                ..
#                     Red Dead Redemption 2  Satisfactory                         1
#                                            SCUM                                 1
#                                            Retro                                1
#                                            PLAYERUNKNOWN                        1
# osu!                Slots                  League of Legends                    1
# Length: 6048, dtype: int64

# %%
games = df10.head(15)
games1 = df12.head(15)
games2 = df14.head(15)
vertical_stack = pd.concat([games, games1, games2], axis=0)
df30 = vertical_stack.rename_axis('games').reset_index(name='counts')
df31 = df30.groupby(["games"]).counts.sum().reset_index()
df31
# Out:
#                                games  counts
# 0                           Among Us     745
# 1      Animal Crossing: New Horizons     235
# 2                       Apex Legends     267
# 3       Call Of Duty: Modern Warfare    1117
# 4   Counter-Strike: Global Offensive     663
# 5                   Dead by Daylight     145
# 6                             Dota 2     213
# 7                 Escape From Tarkov     521
# 8                            FIFA 20     198
# 9                            FIFA 21     113
# 10      Fall Guys: Ultimate Knockout     460
# 11                          Fortnite     730
# 12                Grand Theft Auto V     929
# 13                       Hearthstone     163
# 14                     Just Chatting    3421
# 15                 League of Legends    1331
# 16                         Minecraft     599
# 17                 Teamfight Tactics     217
# 18                Unlisted on Twitch     422
# 19                          VALORANT    1206
# 20                 World of Warcraft     246

# %%
matplotlib.style.use('fivethirtyeight') 
df32 = (
    df31.plot.bar(x = "games", y = "counts", rot = 90)
)
plt.title("All Games Played the Most")
plt.xlabel("Games")
plt.ylabel("Occurances of Game Between Streamers")
df32
# Out:
# <AxesSubplot:title={'center':'All Games Played the Most'}, xlabel='Games', ylabel='Occurances of Game Between Streamers'>
