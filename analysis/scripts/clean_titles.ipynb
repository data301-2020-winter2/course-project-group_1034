# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../../data/raw/twitchdataset.csv')

# %%
data.head()
# Out:
#                                      profile picture  top count screen name  \
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...          1       xQcOW
# 1  https://static-cdn.jtvnw.net/jtv_user_pictures...          2      Gaules
# 2  https://static-cdn.jtvnw.net/jtv_user_pictures...          3    summit1g
# 3  https://static-cdn.jtvnw.net/jtv_user_pictures...          4    ESL_CSGO
# 4  https://static-cdn.jtvnw.net/jtv_user_pictures...          5   NICKMERCS
#
#    watch time  stream time  peak viewers  average viewers  followers  \
# 0  7333609065       215670        222720            32913    3691010
# 1  6314532585       515595        387315            12254    1966465
# 2  6235007490       216000        310998            25931    5374710
# 3  4764929775       517965        300575             9249    4195657
# 4  3853252845       131880        163241            29183    4415637
#
#    followers gained  views gained  partnered  mature    language  \
# 0           2051895     109735389       True   False     English
# 1           1141123     112807468       True    True  Portuguese
# 2           1402547      91501875       True   False     English
# 3            870484     126008641       True   False     English
# 4           1337535      49164651       True   False     English
#
#   completa name                    first category second category  \
# 0         xQcOW                     Just Chatting        Among Us
# 1        Gaules  Counter-Strike: Global Offensive        Among Us
# 2      summit1g                Escape From Tarkov  Sea of Thieves
# 3      ESL_CSGO  Counter-Strike: Global Offensive             NaN
# 4     NICKMERCS      Call Of Duty: Modern Warfare        Fortnite
#
#                       third category
# 0                          Overwatch
# 1                      PLAYERUNKNOWN
# 2                 Grand Theft Auto V
# 3                                NaN
# 4  Halo: The Master Chief Collection

# %%
df = (
    pd.DataFrame(data)
    .rename(columns={"screen name": "Stream Name"})
    .rename(columns={"top count":"Ranking"})
    .rename(columns={"watch time":"Watch Time (Hours)"})
    .rename(columns={"stream time":"Stream Time (Hours)"})
    .rename(columns={"peak viewers":"Viewers (Peak)"})
    .rename(columns={"average viewers":"Viewers (Average)"})
    .rename(columns={"followers":"Followers (Total)"})
    .rename(columns={"followers gained":"Followers (Gained)"})
    .rename(columns={"views gained":"Viewers (Gained)"})
    .rename(columns={"partnered":"Partnered"})
    .rename(columns={"mature":"Audience Type (Mature)"})
    .rename(columns={"language":"Language"})
    .rename(columns={"first category":"Primary Game"})
    .rename(columns={"second category":"Secondary Game"})
    .rename(columns={"third category":"Tertiary Game"})
    .drop("profile picture", axis = 1)
    .drop("completa name", axis = 1)
)

# %%
df
# Out:
#       Ranking       Stream Name  Watch Time (Hours)  Stream Time (Hours)  \
# 0           1             xQcOW          7333609065               215670
# 1           2            Gaules          6314532585               515595
# 2           3          summit1g          6235007490               216000
# 3           4          ESL_CSGO          4764929775               517965
# 4           5         NICKMERCS          3853252845               131880
# ...       ...               ...                 ...                  ...
# 8795     8796  MARCUSakaAPOSTLE             8830110                72495
# 8796     8797     MIMISHKA_MEOW             8829870                96090
# 8797     8798           MySteam             8829075                44400
# 8798     8799        Iker_Guide             8828805               126990
# 8799     8800          dhary_xd             8827995               165105
#
#       Viewers (Peak)  Viewers (Average)  Followers (Total)  \
# 0             222720              32913            3691010
# 1             387315              12254            1966465
# 2             310998              25931            5374710
# 3             300575               9249            4195657
# 4             163241              29183            4415637
# ...              ...                ...                ...
# 8795            2671                 75              20896
# 8796            2039                 89              14805
# 8797            1158                180              11134
# 8798             433                 67              34409
# 8799            2270                 50               9194
#
#       Followers (Gained)  Viewers (Gained)  Partnered  Audience Type (Mature)  \
# 0                2051895         109735389       True                   False
# 1                1141123         112807468       True                    True
# 2                1402547          91501875       True                   False
# 3                 870484         126008641       True                   False
# 4                1337535          49164651       True                   False
# ...                  ...               ...        ...                     ...
# 8795               19618            190090       True                   False
# 8796                3204            398018      False                    True
# 8797               10273            264848      False                   False
# 8798                5245            243384       True                    True
# 8799                2921            927197      False                   False
#
#         Language                      Primary Game     Secondary Game  \
# 0        English                     Just Chatting           Among Us
# 1     Portuguese  Counter-Strike: Global Offensive           Among Us
# 2        English                Escape From Tarkov     Sea of Thieves
# 3        English  Counter-Strike: Global Offensive                NaN
# 4        English      Call Of Duty: Modern Warfare           Fortnite
# ...          ...                               ...                ...
# 8795     English                        Spellbreak      Rogue Company
# 8796     Russian                         Overwatch      Just Chatting
# 8797       Other                            Dota 2      Just Chatting
# 8798      French                          Paladins  League of Legends
# 8799     English                             Music      PLAYERUNKNOWN
#
#                           Tertiary Game
# 0                             Overwatch
# 1                         PLAYERUNKNOWN
# 2                    Grand Theft Auto V
# 3                                   NaN
# 4     Halo: The Master Chief Collection
# ...                                 ...
# 8795                       Apex Legends
# 8796                       Apex Legends
# 8797       Fall Guys: Ultimate Knockout
# 8798                              SMITE
# 8799                          Destiny 2
#
# [8800 rows x 15 columns]

# %%
df1 = (
    df.head(20).style.set_table_styles(
        [{'selector': 'th',
        'props': [('background', '#6441A4'),
             ('color', 'white'),
             ('font-family', 'verdana')]},
     
        {'selector': 'td',
        'props': [('font-family', 'verdana')]},
     
         {'selector': 'tr:nth-of-type(odd)',
         'props': [('background', '#DCDCDC')]},
     
         {'selector': 'tr:nth-of-type(even)',
         'props': [('background', 'white')]},
     
         {'selector': 'tr:hover',
         'props': [('background-color', '#F5DEF9')]}
        ]
    
    ).hide_index()
    
)
df1
# Out:
# <style  type="text/css" >
#     #T_3f9b8_ th {
#           background: #6441A4;
#           color: white;
#           font-family: verdana;
#     }    #T_3f9b8_ td {
#           font-family: verdana;
#     }    #T_3f9b8_ tr:nth-of-type(odd) {
#           background: #DCDCDC;
#     }    #T_3f9b8_ tr:nth-of-type(even) {
#           background: white;
#     }    #T_3f9b8_ tr:hover {
#           background-color: #F5DEF9;
#     }</style><table id="T_3f9b8_" ><thead>    <tr>        <th class="col_heading level0 col0" >Ranking</th>        <th class="col_heading level0 col1" >Stream Name</th>        <th class="col_heading level0 col2" >Watch Time (Hours)</th>        <th class="col_heading level0 col3" >Stream Time (Hours)</th>        <th class="col_heading level0 col4" >Viewers (Peak)</th>        <th class="col_heading level0 col5" >Viewers (Average)</th>        <th class="col_heading level0 col6" >Followers (Total)</th>        <th class="col_heading level0 col7" >Followers (Gained)</th>        <th class="col_heading level0 col8" >Viewers (Gained)</th>        <th class="col_heading level0 col9" >Partnered</th>        <th class="col_heading level0 col10" >Audience Type (Mature)</th>        <th class="col_heading level0 col11" >Language</th>        <th class="col_heading level0 col12" >Primary Game</th>        <th class="col_heading level0 col13" >Secondary Game</th>        <th class="col_heading level0 col14" >Tertiary Game</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_3f9b8_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_3f9b8_row0_col1" class="data row0 col1" >xQcOW</td>
#                         <td id="T_3f9b8_row0_col2" class="data row0 col2" >7333609065</td>
#                         <td id="T_3f9b8_row0_col3" class="data row0 col3" >215670</td>
#                         <td id="T_3f9b8_row0_col4" class="data row0 col4" >222720</td>
#                         <td id="T_3f9b8_row0_col5" class="data row0 col5" >32913</td>
#                         <td id="T_3f9b8_row0_col6" class="data row0 col6" >3691010</td>
#                         <td id="T_3f9b8_row0_col7" class="data row0 col7" >2051895</td>
#                         <td id="T_3f9b8_row0_col8" class="data row0 col8" >109735389</td>
#                         <td id="T_3f9b8_row0_col9" class="data row0 col9" >True</td>
#                         <td id="T_3f9b8_row0_col10" class="data row0 col10" >False</td>
#                         <td id="T_3f9b8_row0_col11" class="data row0 col11" >English</td>
#                         <td id="T_3f9b8_row0_col12" class="data row0 col12" >Just Chatting</td>
#                         <td id="T_3f9b8_row0_col13" class="data row0 col13" >Among Us</td>
#                         <td id="T_3f9b8_row0_col14" class="data row0 col14" >Overwatch</td>
#             </tr>
#             <tr>
#                                 <td id="T_3f9b8_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_3f9b8_row1_col1" class="data row1 col1" >Gaules</td>
#                         <td id="T_3f9b8_row1_col2" class="data row1 col2" >6314532585</td>
#                         <td id="T_3f9b8_row1_col3" class="data row1 col3" >515595</td>
#                         <td id="T_3f9b8_row1_col4" class="data row1 col4" >387315</td>
#                         <td id="T_3f9b8_row1_col5" class="data row1 col5" >12254</td>
#                         <td id="T_3f9b8_row1_col6" class="data row1 col6" >1966465</td>
#                         <td id="T_3f9b8_row1_col7" class="data row1 col7" >1141123</td>
#                         <td id="T_3f9b8_row1_col8" class="data row1 col8" >112807468</td>
#                         <td id="T_3f9b8_row1_col9" class="data row1 col9" >True</td>
#                         <td id="T_3f9b8_row1_col10" class="data row1 col10" >True</td>
#                         <td id="T_3f9b8_row1_col11" class="data row1 col11" >Portuguese</td>
#                         <td id="T_3f9b8_row1_col12" class="data row1 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_3f9b8_row1_col13" class="data row1 col13" >Among Us</td>
#                         <td id="T_3f9b8_row1_col14" class="data row1 col14" >PLAYERUNKNOWN</td>
#             </tr>
#             <tr>
#                                 <td id="T_3f9b8_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_3f9b8_row2_col1" class="data row2 col1" >summit1g</td>
#                         <td id="T_3f9b8_row2_col2" class="data row2 col2" >6235007490</td>
#                         <td id="T_3f9b8_row2_col3" class="data row2 col3" >216000</td>
#                         <td id="T_3f9b8_row2_col4" class="data row2 col4" >310998</td>
#                         <td id="T_3f9b8_row2_col5" class="data row2 col5" >25931</td>
#                         <td id="T_3f9b8_row2_col6" class="data row2 col6" >5374710</td>
#                         <td id="T_3f9b8_row2_col7" class="data row2 col7" >1402547</td>
#                         <td id="T_3f9b8_row2_col8" class="data row2 col8" >91501875</td>
#                         <td id="T_3f9b8_row2_col9" class="data row2 col9" >True</td>
#                         <td id="T_3f9b8_row2_col10" class="data row2 col10" >False</td>
#                         <td id="T_3f9b8_row2_col11" class="data row2 col11" >English</td>
#                         <td id="T_3f9b8_row2_col12" class="data row2 col12" >Escape From Tarkov</td>
#                         <td id="T_3f9b8_row2_col13" class="data row2 col13" >Sea of Thieves</td>
#                         <td id="T_3f9b8_row2_col14" class="data row2 col14" >Grand Theft Auto V</td>
#             </tr>
#             <tr>
#                                 <td id="T_3f9b8_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_3f9b8_row3_col1" class="data row3 col1" >ESL_CSGO</td>
#                         <td id="T_3f9b8_row3_col2" class="data row3 col2" >4764929775</td>
#                         <td id="T_3f9b8_row3_col3" class="data row3 col3" >517965</td>
#                         <td id="T_3f9b8_row3_col4" class="data row3 col4" >300575</td>
#                         <td id="T_3f9b8_row3_col5" class="data row3 col5" >9249</td>
#                         <td id="T_3f9b8_row3_col6" class="data row3 col6" >4195657</td>
#                         <td id="T_3f9b8_row3_col7" class="data row3 col7" >870484</td>
#                         <td id="T_3f9b8_row3_col8" class="data row3 col8" >126008641</td>
#                         <td id="T_3f9b8_row3_col9" class="data row3 col9" >True</td>
#                         <td id="T_3f9b8_row3_col10" class="data row3 col10" >False</td>
#                         <td id="T_3f9b8_row3_col11" class="data row3 col11" >English</td>
#                         <td id="T_3f9b8_row3_col12" class="data row3 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_3f9b8_row3_col13" class="data row3 col13" >nan</td>
#                         <td id="T_3f9b8_row3_col14" class="data row3 col14" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_3f9b8_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_3f9b8_row4_col1" class="data row4 col1" >NICKMERCS</td>
#                         <td id="T_3f9b8_row4_col2" class="data row4 col2" >3853252845</td>
#                         <td id="T_3f9b8_row4_col3" class="data row4 col3" >131880</td>
#                         <td id="T_3f9b8_row4_col4" class="data row4 col4" >163241</td>
#                         <td id="T_3f9b8_row4_col5" class="data row4 col5" >29183</td>
#                         <td id="T_3f9b8_row4_col6" class="data row4 col6" >4415637</td>
#                         <td id="T_3f9b8_row4_col7" class="data row4 col7" >1337535</td>
#                         <td id="T_3f9b8_row4_col8" class="data row4 col8" >49164651</td>
#                         <td id="T_3f9b8_row4_col9" class="data row4 col9" >True</td>
#                         <td id="T_3f9b8_row4_col10" class="data row4 col10" >False</td>
#                         <td id

# %%
df.head(20).style.bar(color='green')
# Out:
# <style  type="text/css" >
# #T_64031_row0_col0,#T_64031_row3_col5,#T_64031_row9_col3,#T_64031_row19_col2,#T_64031_row19_col4,#T_64031_row19_col6,#T_64031_row19_col7,#T_64031_row19_col8{
#             width:  10em;
#              height:  80%;
#         }#T_64031_row0_col2,#T_64031_row3_col3,#T_64031_row5_col8,#T_64031_row8_col6,#T_64031_row9_col5,#T_64031_row9_col7,#T_64031_row14_col4,#T_64031_row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 100.0%, transparent 100.0%);
#         }#T_64031_row0_col3,#T_64031_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 35.8%, transparent 35.8%);
#         }#T_64031_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 31.2%, transparent 31.2%);
#         }#T_64031_row0_col5,#T_64031_row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 42.8%, transparent 42.8%);
#         }#T_64031_row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 36.7%, transparent 36.7%);
#         }#T_64031_row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 11.4%, transparent 11.4%);
#         }#T_64031_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 5.3%, transparent 5.3%);
#         }#T_64031_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 79.9%, transparent 79.9%);
#         }#T_64031_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 99.5%, transparent 99.5%);
#         }#T_64031_row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 58.4%, transparent 58.4%);
#         }#T_64031_row1_col5,#T_64031_row8_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 5.4%, transparent 5.4%);
#         }#T_64031_row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 16.8%, transparent 16.8%);
#         }#T_64031_row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 23.0%, transparent 23.0%);
#         }#T_64031_row1_col8,#T_64031_row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 11.9%, transparent 11.9%);
#         }#T_64031_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 10.5%, transparent 10.5%);
#         }#T_64031_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 78.3%, transparent 78.3%);
#         }#T_64031_row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 45.8%, transparent 45.8%);
#         }#T_64031_row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 30.2%, transparent 30.2%);
#         }#T_64031_row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 56.1%, transparent 56.1%);
#         }#T_64031_row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 28.7%, transparent 28.7%);
#         }#T_64031_row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 8.6%, transparent 8.6%);
#         }#T_64031_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 15.8%, transparent 15.8%);
#         }#T_64031_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 49.3%, transparent 49.3%);
#         }#T_64031_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 44.1%, transparent 44.1%);
#         }#T_64031_row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 42.5%, transparent 42.5%);
#         }#T_64031_row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 17.1%, transparent 17.1%);
#         }#T_64031_row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 14.0%, transparent 14.0%);
#         }#T_64031_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 21.1%, transparent 21.1%);
#         }#T_64031_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 31.3%, transparent 31.3%);
#         }#T_64031_row4_col3,#T_64031_row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 18.0%, transparent 18.0%);
#         }#T_64031_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 21.4%, transparent 21.4%);
#         }#T_64031_row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 36.1%, transparent 36.1%);
#         }#T_64031_row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 45.1%, transparent 45.1%);
#         }#T_64031_row4_col7,#T_64031_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 27.2%, transparent 27.2%);
#         }#T_64031_row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 2.1%, transparent 2.1%);
#         }#T_64031_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 26.3%, transparent 26.3%);
#         }#T_64031_row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 24.3%, transparent 24.3%);
#         }#T_64031_row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 5.8%, transparent 5.8%);
#         }#T_64031_row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 19.0%, transparent 19.0%);
#         }#T_64031_row5_col6,#T_64031_row16_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 0.3%, transparent 0.3%);
#         }#T_64031_row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 7.6%, transparent 7.6%);
#         }#T_64031_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 31.6%, transparent 31.6%);
#         }#T_64031_row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 24.4%, transparent 24.4%);
#         }#T_64031_row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 17.8%, transparent 17.8%);
#         }#T_64031_row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 30.3%, transparent 30.3%);
#         }#T_64031_row6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 37.0%, transparent 37.0%);
#         }#T_64031_row6_col7{
#             width:  10em

# %%
def load_and_process(url_or_path_to_csv_file):

    df4 = (
          pd.read_csv(url_or_path_to_csv_file)
          .rename(columns={"screen name": "Stream Name"})
        .rename(columns={"top count":"Ranking"})
        .rename(columns={"watch time":"Watch Time (Hours)"})
        .rename(columns={"stream time":"Stream Time (Hours)"})
        .rename(columns={"peak viewers":"Viewers (Peak)"})
        .rename(columns={"average viewers":"Viewers (Average)"})
        .rename(columns={"followers":"Followers (Total)"})
        .rename(columns={"followers gained":"Followers (Gained)"})
        .rename(columns={"views gained":"Viewers (Gained)"})
        .rename(columns={"partnered":"Partnered"})
        .rename(columns={"mature":"Audience Type (Mature)"})
        .rename(columns={"language":"Language"})
        .rename(columns={"first category":"Primary Game"})
        .rename(columns={"second category":"Secondary Game"})
        .rename(columns={"third category":"Tertiary Game"})
        .drop("profile picture", axis = 1)
        .drop("completa name", axis = 1)
      )

    df5 = (
    df4.head(20).style.set_table_styles(
        [{'selector': 'th',
        'props': [('background', '#6441A4'),
             ('color', 'white'),
             ('font-family', 'verdana')]},
     
        {'selector': 'td',
        'props': [('font-family', 'verdana')]},
     
         {'selector': 'tr:nth-of-type(odd)',
         'props': [('background', '#DCDCDC')]},
     
         {'selector': 'tr:nth-of-type(even)',
         'props': [('background', 'white')]},
     
         {'selector': 'tr:hover',
         'props': [('background-color', '#F5DEF9')]}
        ]
    
    ).hide_index()
    
    )

    return df5

# %%
load_and_process('../../data/raw/twitchdataset.csv')
# Out:
# <style  type="text/css" >
#     #T_a6d6d_ th {
#           background: #6441A4;
#           color: white;
#           font-family: verdana;
#     }    #T_a6d6d_ td {
#           font-family: verdana;
#     }    #T_a6d6d_ tr:nth-of-type(odd) {
#           background: #DCDCDC;
#     }    #T_a6d6d_ tr:nth-of-type(even) {
#           background: white;
#     }    #T_a6d6d_ tr:hover {
#           background-color: #F5DEF9;
#     }</style><table id="T_a6d6d_" ><thead>    <tr>        <th class="col_heading level0 col0" >Ranking</th>        <th class="col_heading level0 col1" >Stream Name</th>        <th class="col_heading level0 col2" >Watch Time (Hours)</th>        <th class="col_heading level0 col3" >Stream Time (Hours)</th>        <th class="col_heading level0 col4" >Viewers (Peak)</th>        <th class="col_heading level0 col5" >Viewers (Average)</th>        <th class="col_heading level0 col6" >Followers (Total)</th>        <th class="col_heading level0 col7" >Followers (Gained)</th>        <th class="col_heading level0 col8" >Viewers (Gained)</th>        <th class="col_heading level0 col9" >Partnered</th>        <th class="col_heading level0 col10" >Audience Type (Mature)</th>        <th class="col_heading level0 col11" >Language</th>        <th class="col_heading level0 col12" >Primary Game</th>        <th class="col_heading level0 col13" >Secondary Game</th>        <th class="col_heading level0 col14" >Tertiary Game</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a6d6d_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_a6d6d_row0_col1" class="data row0 col1" >xQcOW</td>
#                         <td id="T_a6d6d_row0_col2" class="data row0 col2" >7333609065</td>
#                         <td id="T_a6d6d_row0_col3" class="data row0 col3" >215670</td>
#                         <td id="T_a6d6d_row0_col4" class="data row0 col4" >222720</td>
#                         <td id="T_a6d6d_row0_col5" class="data row0 col5" >32913</td>
#                         <td id="T_a6d6d_row0_col6" class="data row0 col6" >3691010</td>
#                         <td id="T_a6d6d_row0_col7" class="data row0 col7" >2051895</td>
#                         <td id="T_a6d6d_row0_col8" class="data row0 col8" >109735389</td>
#                         <td id="T_a6d6d_row0_col9" class="data row0 col9" >True</td>
#                         <td id="T_a6d6d_row0_col10" class="data row0 col10" >False</td>
#                         <td id="T_a6d6d_row0_col11" class="data row0 col11" >English</td>
#                         <td id="T_a6d6d_row0_col12" class="data row0 col12" >Just Chatting</td>
#                         <td id="T_a6d6d_row0_col13" class="data row0 col13" >Among Us</td>
#                         <td id="T_a6d6d_row0_col14" class="data row0 col14" >Overwatch</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6d6d_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_a6d6d_row1_col1" class="data row1 col1" >Gaules</td>
#                         <td id="T_a6d6d_row1_col2" class="data row1 col2" >6314532585</td>
#                         <td id="T_a6d6d_row1_col3" class="data row1 col3" >515595</td>
#                         <td id="T_a6d6d_row1_col4" class="data row1 col4" >387315</td>
#                         <td id="T_a6d6d_row1_col5" class="data row1 col5" >12254</td>
#                         <td id="T_a6d6d_row1_col6" class="data row1 col6" >1966465</td>
#                         <td id="T_a6d6d_row1_col7" class="data row1 col7" >1141123</td>
#                         <td id="T_a6d6d_row1_col8" class="data row1 col8" >112807468</td>
#                         <td id="T_a6d6d_row1_col9" class="data row1 col9" >True</td>
#                         <td id="T_a6d6d_row1_col10" class="data row1 col10" >True</td>
#                         <td id="T_a6d6d_row1_col11" class="data row1 col11" >Portuguese</td>
#                         <td id="T_a6d6d_row1_col12" class="data row1 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_a6d6d_row1_col13" class="data row1 col13" >Among Us</td>
#                         <td id="T_a6d6d_row1_col14" class="data row1 col14" >PLAYERUNKNOWN</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6d6d_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_a6d6d_row2_col1" class="data row2 col1" >summit1g</td>
#                         <td id="T_a6d6d_row2_col2" class="data row2 col2" >6235007490</td>
#                         <td id="T_a6d6d_row2_col3" class="data row2 col3" >216000</td>
#                         <td id="T_a6d6d_row2_col4" class="data row2 col4" >310998</td>
#                         <td id="T_a6d6d_row2_col5" class="data row2 col5" >25931</td>
#                         <td id="T_a6d6d_row2_col6" class="data row2 col6" >5374710</td>
#                         <td id="T_a6d6d_row2_col7" class="data row2 col7" >1402547</td>
#                         <td id="T_a6d6d_row2_col8" class="data row2 col8" >91501875</td>
#                         <td id="T_a6d6d_row2_col9" class="data row2 col9" >True</td>
#                         <td id="T_a6d6d_row2_col10" class="data row2 col10" >False</td>
#                         <td id="T_a6d6d_row2_col11" class="data row2 col11" >English</td>
#                         <td id="T_a6d6d_row2_col12" class="data row2 col12" >Escape From Tarkov</td>
#                         <td id="T_a6d6d_row2_col13" class="data row2 col13" >Sea of Thieves</td>
#                         <td id="T_a6d6d_row2_col14" class="data row2 col14" >Grand Theft Auto V</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6d6d_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_a6d6d_row3_col1" class="data row3 col1" >ESL_CSGO</td>
#                         <td id="T_a6d6d_row3_col2" class="data row3 col2" >4764929775</td>
#                         <td id="T_a6d6d_row3_col3" class="data row3 col3" >517965</td>
#                         <td id="T_a6d6d_row3_col4" class="data row3 col4" >300575</td>
#                         <td id="T_a6d6d_row3_col5" class="data row3 col5" >9249</td>
#                         <td id="T_a6d6d_row3_col6" class="data row3 col6" >4195657</td>
#                         <td id="T_a6d6d_row3_col7" class="data row3 col7" >870484</td>
#                         <td id="T_a6d6d_row3_col8" class="data row3 col8" >126008641</td>
#                         <td id="T_a6d6d_row3_col9" class="data row3 col9" >True</td>
#                         <td id="T_a6d6d_row3_col10" class="data row3 col10" >False</td>
#                         <td id="T_a6d6d_row3_col11" class="data row3 col11" >English</td>
#                         <td id="T_a6d6d_row3_col12" class="data row3 col12" >Counter-Strike: Global Offensive</td>
#                         <td id="T_a6d6d_row3_col13" class="data row3 col13" >nan</td>
#                         <td id="T_a6d6d_row3_col14" class="data row3 col14" >nan</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6d6d_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_a6d6d_row4_col1" class="data row4 col1" >NICKMERCS</td>
#                         <td id="T_a6d6d_row4_col2" class="data row4 col2" >3853252845</td>
#                         <td id="T_a6d6d_row4_col3" class="data row4 col3" >131880</td>
#                         <td id="T_a6d6d_row4_col4" class="data row4 col4" >163241</td>
#                         <td id="T_a6d6d_row4_col5" class="data row4 col5" >29183</td>
#                         <td id="T_a6d6d_row4_col6" class="data row4 col6" >4415637</td>
#                         <td id="T_a6d6d_row4_col7" class="data row4 col7" >1337535</td>
#                         <td id="T_a6d6d_row4_col8" class="data row4 col8" >49164651</td>
#                         <td id="T_a6d6d_row4_col9" class="data row4 col9" >True</td>
#                         <td id="T_a6d6d_row4_col10" class="data row4 col10" >False</td>
#                         <td id
